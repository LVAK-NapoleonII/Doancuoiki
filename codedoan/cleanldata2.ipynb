# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_data.csv")
df
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0      id       author  \
# 0                 0             1           1  218269   doãn hằng
# 1                 1             4           4  218266       mi lan
# 2                 2             5           5  218265    đặng tiến
# 3                 3             9           9  218261    minh quân
# 4                 4            10          10  218260  linh nguyên
# ...             ...           ...         ...     ...          ...
# 97077         97077        184532      184532       7     hoàng vũ
# 97078         97078        184534      184534       5  Minh Phương
# 97079         97079        184535      184535       4   Thiên Bình
# 97080         97080        184536      184536       3      Đại Nam
# 97081         97081        184537      184537       2   Trần Chung
#
#                                                  content  picture_count  \
# 0      Gần đây, Thứ trưởng Bộ Phát triển Kỹ thuật số,...              1
# 1      Vụ tai nạn giao thông liên hoàn phố đi Tam Bạc...             12
# 2      Chia sẻ Twitter, thị trưởng Hanover Belit Onay...              2
# 3      Siêu Bồ Đào Nha HLV Erik ten Hag bố trí đá Val...              1
# 4      Nỗi lo cửa chậm sửa chữa hết, hàng ngày, lao đ...              0
# ...                                                  ...            ...
# 97077  Hôm qua, Talk Sports xuất hiện viết Việt Nam t...              2
# 97078  Chiều 7/6, Khoa Công an Phú Nhuận phối hợp Côn...              2
# 97079  Ngày 7/6, phiên xử phúc thẩm Tất Thành Cang, 5...              2
# 97080  Các khu dân cư thành phố Severodonetsk hoàn to...              2
# 97081  Việt Nam - Malaysia: 20h Tư 8/6, VnExpress. Ma...              2
#
#        processed      source  \
# 0              0      vtc.vn
# 1              0        soha
# 2              0  tuoitre.vn
# 3              0  bongdaplus
# 4              0     danviet
# ...          ...         ...
# 97077          1   vnexpress
# 97078          1   vnexpress
# 97079          1   vnexpress
# 97080          1   vnexpress
# 97081          1   vnexpress
#
#                                                    title                topic  \
# 0                       Bỏ mạng 5G, Nga tiến thẳng 4G 6G  Sức khỏe - Đời sống
# 1      Hải Phòng: Hình ảnh xe "điên" tai nạn liên hoà...              Thời sự
# 2                              Đức thể suy thoái kinh tế             Thế giới
# 3                      Bị thay hiệp 1, Ronaldo đùng đùng             Thể thao
# 4      Hà Nội: Người lao động than trời khu công nhân...               Xã hội
# ...                                                  ...                  ...
# 97077           CĐV Trung Quốc lo ngại tiến U23 Việt Nam             Thể thao
# 97078                               Nghi can sát hại bắt            Pháp luật
# 97079                      Ông Tất Thành Cang đề nghị án            Pháp luật
# 97080  Nga tuyên bố 'giải phóng' hoàn toàn khu dân cư...             Thế giới
# 97081              HLV Malaysia dọa ngáng đường Việt Nam             Thể thao
#
#                                                      url
# 0      https://vtc.vn/bo-qua-mang-5g-nga-tien-thang-t...
# 1      https://soha.vn/hai-phong-hinh-anh-xe-dien-gay...
# 2      https://tuoitre.vn/duc-co-the-suy-thoai-kinh-t...
# 3      https://bongdaplus.vn/ngoai-hang-anh/ronaldo-d...
# 4      https://danviet.vn/ha-noi-nguoi-lao-dong-than-...
# ...                                                  ...
# 97077  https://vnexpress.net/cdv-trung-quoc-lo-ngai-s...
# 97078  https://vnexpress.net/nghi-can-sat-hai-cha-bi-...
# 97079  https://vnexpress.net/ong-tat-thanh-cang-duoc-...
# 97080  https://vnexpress.net/nga-tuyen-bo-giai-phong-...
# 97081  https://vnexpress.net/hlv-malaysia-doa-ngang-d...
#
# [97082 rows x 12 columns]

# %%
for x in df.index:
    if df.loc[x, "processed"] == 0:
        df.drop(x, inplace=True)
for x in df.index:
    if df.loc[x, "source"] == '':
        df.drop(x, inplace=True)

df
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0      id       author  \
# 102             102           155         155  218114   yến phương
# 103             103           156         156  218113     phúc đạt
# 104             104           157         157  218112    thùy linh
# 105             105           159         159  218110     gia miêu
# 106             106           160         160  218108      hạ mây
# ...             ...           ...         ...     ...          ...
# 97077         97077        184532      184532       7     hoàng vũ
# 97078         97078        184534      184534       5  Minh Phương
# 97079         97079        184535      184535       4   Thiên Bình
# 97080         97080        184536      184536       3      Đại Nam
# 97081         97081        184537      184537       2   Trần Chung
#
#                                                  content  picture_count  \
# 102    Dịch bệnh ảnh hưởng yếu tố bất lợi lẫn doanh n...              0
# 103    Đăng quang vị Á quân 2 - Miss International Qu...              0
# 104    Tối 31-7, ĐH Quốc gia Hà Nội gửi công văn Hiệu...              2
# 105    Sự bé gái 8 TP.HCM dì ghẻ bạo hành tử vong 202...              1
# 106                                       Theo Dailymail              5
# ...                                                  ...            ...
# 97077  Hôm qua, Talk Sports xuất hiện viết Việt Nam t...              2
# 97078  Chiều 7/6, Khoa Công an Phú Nhuận phối hợp Côn...              2
# 97079  Ngày 7/6, phiên xử phúc thẩm Tất Thành Cang, 5...              2
# 97080  Các khu dân cư thành phố Severodonetsk hoàn to...              2
# 97081  Việt Nam - Malaysia: 20h Tư 8/6, VnExpress. Ma...              2
#
#        processed        source  \
# 102            1        vtv.vn
# 103            1        eva.vn
# 104            1     docbao.vn
# 105            1  thanhnien.vn
# 106            1        kenh14
# ...          ...           ...
# 97077          1     vnexpress
# 97078          1     vnexpress
# 97079          1     vnexpress
# 97080          1     vnexpress
# 97081          1     vnexpress
#
#                                                    title                topic  \
# 102                   Hoạt động sản xuất Trung Quốc chậm              Kinh tế
# 103    "Tiên nữ Đắk Nia" diện áo tắm soi thấu hao hao...  Sức khỏe - Đời sống
# 104    Giám đốc ĐH Quốc gia Hà Nội tiếng vụ Hiệu trưở...               Xã hội
# 105                                  Người hàng xóm bụng               Xã hội
# 106    Siêu mẫu nội y Shanina Shaik bầu "vượt mặt" qu...   Văn hóa - Giải trí
# ...                                                  ...                  ...
# 97077           CĐV Trung Quốc lo ngại tiến U23 Việt Nam             Thể thao
# 97078                               Nghi can sát hại bắt            Pháp luật
# 97079                      Ông Tất Thành Cang đề nghị án            Pháp luật
# 97080  Nga tuyên bố 'giải phóng' hoàn toàn khu dân cư...             Thế giới
# 97081              HLV Malaysia dọa ngáng đường Việt Nam             Thể thao
#
#                                                      url
# 102    https://vtv.vn/kinh-te/hoat-dong-san-xuat-cua-...
# 103    https://eva.vn/thoi-trang-sao/tien-nu-dak-nia-...
# 104    https://docbao.vn/xa-hoi/giam-doc-dh-quoc-gia-...
# 105    https://thanhnien.vn/nguoi-hang-xom-tot-bung-p...
# 106    https://kenh14.vn/sieu-mau-noi-y-shanina-shaik...
# ...                                                  ...
# 97077  https://vnexpress.net/cdv-trung-quoc-lo-ngai-s...
# 97078  https://vnexpress.net/nghi-can-sat-hai-cha-bi-...
# 97079  https://vnexpress.net/ong-tat-thanh-cang-duoc-...
# 97080  https://vnexpress.net/nga-tuyen-bo-giai-phong-...
# 97081  https://vnexpress.net/hlv-malaysia-doa-ngang-d...
#
# [96980 rows x 12 columns]

# %%
df = df.drop(columns = "Unnamed: 0.2")
df =df.drop(columns ='Unnamed: 0.1')
df =df.drop(columns ='Unnamed: 0')

# %%
df1 = df.reset_index(drop=True)
df
# Out:
#            id       author                                            content  \
# 102    218114   yến phương  Dịch bệnh ảnh hưởng yếu tố bất lợi lẫn doanh n...
# 103    218113     phúc đạt  Đăng quang vị Á quân 2 - Miss International Qu...
# 104    218112    thùy linh  Tối 31-7, ĐH Quốc gia Hà Nội gửi công văn Hiệu...
# 105    218110     gia miêu  Sự bé gái 8 TP.HCM dì ghẻ bạo hành tử vong 202...
# 106    218108      hạ mây                                      Theo Dailymail
# ...       ...          ...                                                ...
# 97077       7     hoàng vũ  Hôm qua, Talk Sports xuất hiện viết Việt Nam t...
# 97078       5  Minh Phương  Chiều 7/6, Khoa Công an Phú Nhuận phối hợp Côn...
# 97079       4   Thiên Bình  Ngày 7/6, phiên xử phúc thẩm Tất Thành Cang, 5...
# 97080       3      Đại Nam  Các khu dân cư thành phố Severodonetsk hoàn to...
# 97081       2   Trần Chung  Việt Nam - Malaysia: 20h Tư 8/6, VnExpress. Ma...
#
#        picture_count  processed        source  \
# 102                0          1        vtv.vn
# 103                0          1        eva.vn
# 104                2          1     docbao.vn
# 105                1          1  thanhnien.vn
# 106                5          1        kenh14
# ...              ...        ...           ...
# 97077              2          1     vnexpress
# 97078              2          1     vnexpress
# 97079              2          1     vnexpress
# 97080              2          1     vnexpress
# 97081              2          1     vnexpress
#
#                                                    title                topic  \
# 102                   Hoạt động sản xuất Trung Quốc chậm              Kinh tế
# 103    "Tiên nữ Đắk Nia" diện áo tắm soi thấu hao hao...  Sức khỏe - Đời sống
# 104    Giám đốc ĐH Quốc gia Hà Nội tiếng vụ Hiệu trưở...               Xã hội
# 105                                  Người hàng xóm bụng               Xã hội
# 106    Siêu mẫu nội y Shanina Shaik bầu "vượt mặt" qu...   Văn hóa - Giải trí
# ...                                                  ...                  ...
# 97077           CĐV Trung Quốc lo ngại tiến U23 Việt Nam             Thể thao
# 97078                               Nghi can sát hại bắt            Pháp luật
# 97079                      Ông Tất Thành Cang đề nghị án            Pháp luật
# 97080  Nga tuyên bố 'giải phóng' hoàn toàn khu dân cư...             Thế giới
# 97081              HLV Malaysia dọa ngáng đường Việt Nam             Thể thao
#
#                                                      url
# 102    https://vtv.vn/kinh-te/hoat-dong-san-xuat-cua-...
# 103    https://eva.vn/thoi-trang-sao/tien-nu-dak-nia-...
# 104    https://docbao.vn/xa-hoi/giam-doc-dh-quoc-gia-...
# 105    https://thanhnien.vn/nguoi-hang-xom-tot-bung-p...
# 106    https://kenh14.vn/sieu-mau-noi-y-shanina-shaik...
# ...                                                  ...
# 97077  https://vnexpress.net/cdv-trung-quoc-lo-ngai-s...
# 97078  https://vnexpress.net/nghi-can-sat-hai-cha-bi-...
# 97079  https://vnexpress.net/ong-tat-thanh-cang-duoc-...
# 97080  https://vnexpress.net/nga-tuyen-bo-giai-phong-...
# 97081  https://vnexpress.net/hlv-malaysia-doa-ngang-d...
#
# [96980 rows x 9 columns]

# %%
df2 = df1.dropna()

# %%
df2.isnull().sum()
# Out:
# id               0
# author           0
# content          0
# picture_count    0
# processed        0
# source           0
# title            0
# topic            0
# url              0
# dtype: int64

# %%
df2.to_csv("cleaned_data_1.csv")
